# %% [markdown]
# ## Data Visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

plt.style.use('fivethirtyeight')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
players = pd.read_csv('../Data/players_stats_and_salaries.csv')
teams = pd.read_csv('../Data/league_scoring.csv')

# %%
# teams_master = sixers.append([bucks,bulls,cavaliers,celtics,clippers,grizzlies,hawks,heat,hornets,jazz,kings,knicks,lakers,magic,mavericks,nets,nuggets,pacers,pelicans,pistons,raptors,rockets,spurs,suns,thunder,timberwolves,blazers,warriors,wizards])
# teams_master.to_csv('../Data/Teams/teams_master.csv')

# %%
teams_master = pd.read_csv('../Data/Teams/teams_master.csv')

# %%
sixers=pd.read_csv('../Data/Teams/76ers.csv')
bucks=pd.read_csv('../Data/Teams/Bucks.csv')
bulls=pd.read_csv('../Data/Teams/Bulls.csv')
cavaliers=pd.read_csv('../Data/Teams/Cavaliers.csv')
celtics=pd.read_csv('../Data/Teams/Celtics.csv')
clippers=pd.read_csv('../Data/Teams/Clippers.csv')
grizzlies=pd.read_csv('../Data/Teams/Grizzlies.csv')
hawks=pd.read_csv('../Data/Teams/Hawks.csv')
heat=pd.read_csv('../Data/Teams/Heat.csv')
hornets=pd.read_csv('../Data/Teams/Hornets.csv')
jazz=pd.read_csv('../Data/Teams/Jazz.csv')
kings=pd.read_csv('../Data/Teams/Kings.csv')
knicks=pd.read_csv('../Data/Teams/Knicks.csv')
lakers=pd.read_csv('../Data/Teams/Lakers.csv')
magic=pd.read_csv('../Data/Teams/Magic.csv')
mavericks=pd.read_csv('../Data/Teams/Mavericks.csv')
nets=pd.read_csv('../Data/Teams/Nets.csv')
nuggets=pd.read_csv('../Data/Teams/Nuggets.csv')
pacers=pd.read_csv('../Data/Teams/Pacers.csv')
pelicans=pd.read_csv('../Data/Teams/Pelicans.csv')
pistons=pd.read_csv('../Data/Teams/Pistons.csv')
raptors=pd.read_csv('../Data/Teams/Raptors.csv')
rockets=pd.read_csv('../Data/Teams/Rockets.csv')
spurs=pd.read_csv('../Data/Teams/Spurs.csv')
suns=pd.read_csv('../Data/Teams/Suns.csv')
thunder=pd.read_csv('../Data/Teams/Thunder.csv')
timberwolves=pd.read_csv('../Data/Teams/Timberwolves.csv')
blazers=pd.read_csv('../Data/Teams/Trail Blazers.csv')
warriors=pd.read_csv('../Data/Teams/Warriors.csv')
wizards=pd.read_csv('../Data/Teams/Wizards.csv')

# %%
teams=teams.iloc[-37:-1]

sixers=sixers.iloc[-37:-1]
bucks=bucks.iloc[-37:-1]
bulls=bulls.iloc[-37:-1]
cavaliers=cavaliers.iloc[-37:-1]
celtics=celtics.iloc[-37:-1]
clippers=clippers.iloc[-37:-1]
grizzlies=grizzlies.iloc[-37:-1]
hawks=hawks.iloc[-37:-1]
heat=heat.iloc[-37:-1]
hornets=hornets.iloc[-37:-1]
jazz=jazz.iloc[-37:-1]
kings=kings.iloc[-37:-1]
knicks=knicks.iloc[-37:-1]
lakers=lakers.iloc[-37:-1]
magic=magic.iloc[-37:-1]
mavericks=mavericks.iloc[-37:-1]
nets=nets.iloc[-37:-1]
nuggets=nuggets.iloc[-37:-1]
pacers=pacers.iloc[-37:-1]
pelicans=pelicans.iloc[-37:-1]
pistons=pistons.iloc[-37:-1]
raptors=raptors.iloc[-37:-1]
rockets=rockets.iloc[-37:-1]
spurs=spurs.iloc[-37:-1]
suns=suns.iloc[-37:-1]
thunder=thunder.iloc[-37:-1]
timberwolves=timberwolves.iloc[-37:-1]
blazers=blazers.iloc[-37:-1]
warriors=warriors.iloc[-37:-1]
wizards=wizards.iloc[-37:-1]

# %%
teams['YEAR']=pd.to_datetime(teams['YEAR'])
teams.set_index('YEAR', inplace=True)

sixers['YEAR']=pd.to_datetime(sixers['YEAR'])
sixers.set_index('YEAR', inplace=True)

bucks['YEAR']=pd.to_datetime(bucks['YEAR'])
bucks.set_index('YEAR', inplace=True)

bulls['YEAR']=pd.to_datetime(bulls['YEAR'])
bulls.set_index('YEAR', inplace=True)

cavaliers['YEAR']=pd.to_datetime(cavaliers['YEAR'])
cavaliers.set_index('YEAR', inplace=True)

celtics['YEAR']=pd.to_datetime(celtics['YEAR'])
celtics.set_index('YEAR', inplace=True)

clippers['YEAR']=pd.to_datetime(clippers['YEAR'])
clippers.set_index('YEAR', inplace=True)

grizzlies['YEAR']=pd.to_datetime(grizzlies['YEAR'])
grizzlies.set_index('YEAR', inplace=True)

hawks['YEAR']=pd.to_datetime(hawks['YEAR'])
hawks.set_index('YEAR', inplace=True)

heat['YEAR']=pd.to_datetime(heat['YEAR'])
heat.set_index('YEAR', inplace=True)

hornets['YEAR']=pd.to_datetime(hornets['YEAR'])
hornets.set_index('YEAR', inplace=True)

jazz['YEAR']=pd.to_datetime(jazz['YEAR'])
jazz.set_index('YEAR', inplace=True)

kings['YEAR']=pd.to_datetime(kings['YEAR'])
kings.set_index('YEAR', inplace=True)

knicks['YEAR']=pd.to_datetime(knicks['YEAR'])
knicks.set_index('YEAR', inplace=True)

lakers['YEAR']=pd.to_datetime(lakers['YEAR'])
lakers.set_index('YEAR', inplace=True)

magic['YEAR']=pd.to_datetime(magic['YEAR'])
magic.set_index('YEAR', inplace=True)

mavericks['YEAR']=pd.to_datetime(mavericks['YEAR'])
mavericks.set_index('YEAR', inplace=True)

nets['YEAR']=pd.to_datetime(nets['YEAR'])
nets.set_index('YEAR', inplace=True)

nuggets['YEAR']=pd.to_datetime(nuggets['YEAR'])
nuggets.set_index('YEAR', inplace=True)

pacers['YEAR']=pd.to_datetime(pacers['YEAR'])
pacers.set_index('YEAR', inplace=True)

pelicans['YEAR']=pd.to_datetime(pelicans['YEAR'])
pelicans.set_index('YEAR', inplace=True)

pistons['YEAR']=pd.to_datetime(pistons['YEAR'])
pistons.set_index('YEAR', inplace=True)

raptors['YEAR']=pd.to_datetime(raptors['YEAR'])
raptors.set_index('YEAR', inplace=True)

rockets['YEAR']=pd.to_datetime(rockets['YEAR'])
rockets.set_index('YEAR', inplace=True)

spurs['YEAR']=pd.to_datetime(spurs['YEAR'])
spurs.set_index('YEAR', inplace=True)

suns['YEAR']=pd.to_datetime(suns['YEAR'])
suns.set_index('YEAR', inplace=True)

thunder['YEAR']=pd.to_datetime(thunder['YEAR'])
thunder.set_index('YEAR', inplace=True)

timberwolves['YEAR']=pd.to_datetime(timberwolves['YEAR'])
timberwolves.set_index('YEAR', inplace=True)

blazers['YEAR']=pd.to_datetime(blazers['YEAR'])
blazers.set_index('YEAR', inplace=True)

warriors['YEAR']=pd.to_datetime(warriors['YEAR'])
warriors.set_index('YEAR', inplace=True)

wizards['YEAR']=pd.to_datetime(wizards['YEAR'])
wizards.set_index('YEAR', inplace=True)

# %%
teams_master['YEAR']=pd.to_datetime(teams_master['YEAR'])
teams_master.set_index('YEAR', inplace=True)

# %%
teams_master['Wins'] = teams_master['WINS']/teams_master['GP']*82

# %%
teams['FGA_PER_GP']=teams['FGA']/teams['GP']

# %%
players['3PA/GP']=players['attempted_three_point_field_goals']/players['games_played']

# %%
players['salary'] = players['Salary'].str.replace(',', '')
players['salary'] = players['salary'].str.replace('$', '')
players['salary'] = players['salary'].astype(int)

# %%
# creates dictionary of entire leagues salaries summed

league_tot_salary = players.groupby('season')['salary'].sum().to_dict()

# %%
for year in range(1990,2019):
    players.loc[players.season == year, 'salary_normalized_%'] = players['salary']/league_tot_salary[year]*100

# %%
for year in range(1990,2019):
    players.loc[players.season == year, 'FG3A_rank'] = players.loc[players.season == year, 'attempted_three_point_field_goals'].rank(ascending=False)
    players.loc[players.season == year, 'FG3M_rank'] = players.loc[players.season == year, 'made_three_point_field_goals'].rank(ascending=False)

# %%
for year in range(1983,2019):
    teams_master.loc[teams_master.index.year == year, 'FG3A/FG2A_rank'] = teams_master.loc[teams_master.index.year == year, 'FG3A/FG2A'].rank(ascending=False)

# %%
teams_master.head()
# Out:
#             Unnamed: 0     TEAM_ID     TEAM_CITY TEAM_NAME  GP  WINS  LOSSES  \
# YEAR
# 1983-01-01          34  1610612755  Philadelphia     76ers  82    52      30
# 1984-01-01          35  1610612755  Philadelphia     76ers  82    58      24
# 1985-01-01          36  1610612755  Philadelphia     76ers  82    54      28
# 1986-01-01          37  1610612755  Philadelphia     76ers  82    45      37
# 1987-01-01          38  1610612755  Philadelphia     76ers  82    36      46
#
#             WIN_PCT  CONF_RANK  DIV_RANK  PO_WINS  PO_LOSSES  CONF_COUNT  \
# YEAR
# 1983-01-01    0.634          3         2        2          3        11.0
# 1984-01-01    0.707          3         2        8          5        11.0
# 1985-01-01    0.659          3         2        6          6        11.0
# 1986-01-01    0.549          5         2        2          3        11.0
# 1987-01-01    0.439         10         4        0          0        11.0
#
# ...

# %%
# 2 pointers attempted per game vs 3 pointers attempted per game over time

plt.figure(figsize=(12,9))
plt.plot(teams['FG2A_PER_GP'],color='blue',marker='o')
plt.plot(teams['FG3A_PER_GP'],color='orange',marker='o')
plt.plot(teams['FGA_PER_GP'],color='green',marker='o');

# 1994 and 1995 3-pt line shortened

# %%
plt.figure(figsize=(12,9))
plt.plot(teams['PTS_PER_GP'],color='blue',marker='o')
plt.plot(teams['FGA_PER_GP'],color='green',marker='o');

# %%
plt.figure(figsize=(12,9))
plt.plot(teams['FG2M_PER_GP'],color='blue',marker='o')
plt.plot(teams['FG3M_PER_GP'],color='orange',marker='o');

# %%
plt.figure(figsize=(12,9))
plt.plot(teams['FG2_PCT'],color='blue',marker='o')
plt.plot(teams['FG3_PCT'],color='orange',marker='o')
plt.plot(teams['FG_PCT'],color='green',marker='o');

# %%
plt.figure(figsize=(12,9))
plt.plot(teams['FG2A/FGA'],color='blue',marker='o')
plt.plot(teams['FG3A/FGA'],color='orange',marker='o')
plt.plot(teams['FTA/FGA'],color='green',marker='o')
plt.plot(teams['FG3A/FG2A'],color='red',marker='o');

# %%
plt.figure(figsize=(12,9))
plt.plot(sixers['FG3A/FG2A'],color='blue',label='76ers')
plt.plot(bucks['FG3A/FG2A'],color='darkgreen',label='Bucks')
plt.plot(bulls['FG3A/FG2A'],color='firebrick',label='Bulls')
plt.plot(cavaliers['FG3A/FG2A'],color='orangered',label='Cavaliers')
plt.plot(celtics['FG3A/FG2A'],color='green',label='Celtics')
plt.plot(clippers['FG3A/FG2A'],color='mistyrose',label='Clippers')
plt.plot(grizzlies['FG3A/FG2A'],color='teal',label='Grizzlies')
plt.plot(hawks['FG3A/FG2A'],color='sienna',label='Hawks')
plt.plot(heat['FG3A/FG2A'],color='black',label='Heat')
plt.plot(hornets['FG3A/FG2A'],color='aqua',label='Hornets')
plt.plot(jazz['FG3A/FG2A'],color='purple',label='Jazz')
plt.plot(kings['FG3A/FG2A'],color='blueviolet',label='Kings')
plt.plot(knicks['FG3A/FG2A'],color='darkorange',label='Knicks')
plt.plot(lakers['FG3A/FG2A'],color='yellow',label='Lakers')
plt.plot(magic['FG3A/FG2A'],color='cornflowerblue',label='Magic')
plt.plot(mavericks['FG3A/FG2A'],color='navy',label='Mavericks')
plt.plot(nets['FG3A/FG2A'],color='darkgrey',label='Nets')
plt.plot(nuggets['FG3A/FG2A'],color='gold',label='Nuggets')
plt.plot(pacers['FG3A/FG2A'],color='darkgoldenrod',label='Pacers')
plt.plot(pelicans['FG3A/FG2A'],color='seagreen',label='Pelicans')
plt.plot(pistons['FG3A/FG2A'],color='steelblue',label='Pistons')
plt.plot(raptors['FG3A/FG2A'],color='mediumvioletred',label='Raptors')
plt.plot(rockets['FG3A/FG2A'],color='red',label='Rockets')
plt.plot(spurs['FG3A/FG2A'],color='black',label='Spurs')
plt.plot(suns['FG3A/FG2A'],color='tomato',label='Suns')
plt.plot(thunder['FG3A/FG2A'],color='moccasin',label='Thunder')
plt.plot(timberwolves['FG3A/FG2A'],color='lightsteelblue',label='Timberwolves')
plt.plot(blazers['FG3A/FG2A'],color='darkred',label='Trail Blazers')
plt.plot(warriors['FG3A/FG2A'],color='khaki',label='Warriors')
plt.plot(wizards['FG3A/FG2A'],color='dodgerblue',label='Wizards')

plt.legend();

# %%
df_top_ten=teams_master.loc[teams_master['FG3A/FG2A_rank']<=10][['TEAM_NAME','Wins','PLAYOFFS','FINALS_APPEARANCE','CHAMPS','FG3A/FG2A','FG3A/FG2A_rank']].sort_values(by=['FG3A/FG2A'],ascending=False)
df_top_ten
# Out:
#                 TEAM_NAME       Wins  PLAYOFFS  FINALS_APPEARANCE  CHAMPS  \
# YEAR
# 2018-01-01        Rockets  53.000000         1                  0       0
# 2017-01-01        Rockets  65.000000         1                  0       0
# 2016-01-01        Rockets  55.000000         1                  0       0
# 2018-01-01      Mavericks  33.000000         0                  0       0
# 2018-01-01          Bucks  60.000000         1                  0       0
# 2017-01-01           Nets  28.000000         0                  0       0
# 2018-01-01          Hawks  29.000000         0                  0       0
# 2018-01-01           Nets  42.000000         1                  0       0
# 2016-01-01      Cavaliers  51.000000         1                  1       0
# 2018-01-01        Pistons  41.000000         1                  0       0
# 2018-01-01           Jazz  50.000000         1                  0       0
# 2016-01-01        Celtics  53.000000         1                  0       0
# ...

# %%
df_top_ten_recent=teams_master.loc[(teams_master['FG3A/FG2A_rank']<=10) & (teams_master.index.year>2009)][['TEAM_NAME','Wins','PLAYOFFS','FINALS_APPEARANCE','CHAMPS','FG3A/FG2A','FG3A/FG2A_rank']].sort_values(by=['FG3A/FG2A'],ascending=False)
df_top_ten_recent
# Out:
#                 TEAM_NAME       Wins  PLAYOFFS  FINALS_APPEARANCE  CHAMPS  \
# YEAR
# 2018-01-01        Rockets  53.000000         1                  0       0
# 2017-01-01        Rockets  65.000000         1                  0       0
# 2016-01-01        Rockets  55.000000         1                  0       0
# 2018-01-01      Mavericks  33.000000         0                  0       0
# 2018-01-01          Bucks  60.000000         1                  0       0
# 2017-01-01           Nets  28.000000         0                  0       0
# 2018-01-01          Hawks  29.000000         0                  0       0
# 2018-01-01           Nets  42.000000         1                  0       0
# 2016-01-01      Cavaliers  51.000000         1                  1       0
# 2018-01-01        Pistons  41.000000         1                  0       0
# 2018-01-01           Jazz  50.000000         1                  0       0
# 2016-01-01        Celtics  53.000000         1                  0       0
# ...

# %%
df_top_ten.shape
# Out:
# (360, 7)

# %%
df_top_ten['PLAYOFFS'].value_counts()
# Out:
# 1    253
# 0    107
# Name: PLAYOFFS, dtype: int64

# %%
# percentage of all teams that make playoffs
round(teams_master['PLAYOFFS'].sum()/teams_master.shape[0],4)
# Out:
# 0.5735

# %%
round(253/(253+107),4)
# Out:
# 0.7028

# %%
round(df_top_ten_recent['PLAYOFFS'].sum()/df_top_ten_recent.shape[0],4)
# Out:
# 0.7222

# %%
df_top_ten['FINALS_APPEARANCE'].value_counts()
# Out:
# 0    318
# 1     42
# Name: FINALS_APPEARANCE, dtype: int64

# %%
# percentage of all teams that make the NBA finals
round(teams_master['FINALS_APPEARANCE'].sum()/teams_master.shape[0],4)
# Out:
# 0.0711

# %%
round(42/360,4)
# Out:
# 0.1167

# %%
round(42/72,4)
# Out:
# 0.5833

# %%
round(df_top_ten_recent['FINALS_APPEARANCE'].sum()/df_top_ten_recent.shape[0],4)
# Out:
# 0.1667

# %%
df_top_ten['CHAMPS'].value_counts()
# Out:
# 0    341
# 1     19
# Name: CHAMPS, dtype: int64

# %%
round(19/360,4)
# Out:
# 0.0528

# %%
# percentage of all teams that win the NBA championship
round(teams_master['CHAMPS'].sum()/teams_master.shape[0],4)
# Out:
# 0.0355

# %%
round(19/36,4)
# Out:
# 0.5278

# %%
round(df_top_ten_recent['CHAMPS'].sum()/df_top_ten_recent.shape[0],4)
# Out:
# 0.0667

# %%
# function to sort by desired stat and year

def sort_by_stat(stat,year,asc=False,head=30):
    return teams_master[teams_master.index.year ==year][['TEAM_NAME',stat,'WINS','PLAYOFFS','FINALS_APPEARANCE','CHAMPS']].sort_values(by=[stat],ascending=asc).head(head)

def sort_by_stat_multiyr(stat,year,asc=False,head=30):
    return teams_master[teams_master.index.year >year][['TEAM_NAME',stat,'WINS','PLAYOFFS','FINALS_APPEARANCE','CHAMPS']].sort_values(by=[stat],ascending=asc).head(head)

# %%
players[players.index.year==2018][['name','team','attempted_three_point_field_goals','FG3A_rank','salary_normalized_%']].sort_values(by=['attempted_three_point_field_goals'],ascending=False)
# Out:
#                                 name                         team  \
# year
# 2018-01-01              James Harden         Team.HOUSTON_ROCKETS
# 2018-01-01             Stephen Curry   Team.GOLDEN_STATE_WARRIORS
# 2018-01-01               Paul George   Team.OKLAHOMA_CITY_THUNDER
# 2018-01-01              Kemba Walker       Team.CHARLOTTE_HORNETS
# 2018-01-01               Buddy Hield        Team.SACRAMENTO_KINGS
# 2018-01-01            Damian Lillard  Team.PORTLAND_TRAIL_BLAZERS
# 2018-01-01          D'Angelo Russell           Team.BROOKLYN_NETS
# 2018-01-01               Eric Gordon         Team.HOUSTON_ROCKETS
# 2018-01-01             Klay Thompson   Team.GOLDEN_STATE_WARRIORS
# 2018-01-01              Bradley Beal      Team.WASHINGTON_WIZARDS
# 2018-01-01             Terrence Ross           Team.ORLANDO_MAGIC
# 2018-01-01               Jae Crowder               Team.UTAH_JAZZ
# 2018-01-01             Blake Griffin         Team.DETROIT_PISTONS
# ...

# %%
sort_by_stat_multiyr('FG3A/FG2A',1982)
# Out:
#             TEAM_NAME  FG3A/FG2A  WINS  PLAYOFFS  FINALS_APPEARANCE  CHAMPS
# YEAR
# 2018-01-01    Rockets   1.081058    53         1                  0       0
# 2017-01-01    Rockets   1.009895    65         1                  0       0
# 2016-01-01    Rockets   0.859594    55         1                  0       0
# 2018-01-01  Mavericks   0.728641    33         0                  0       0
# 2018-01-01      Bucks   0.722619    60         1                  0       0
# 2017-01-01       Nets   0.697852    28         0                  0       0
# 2018-01-01      Hawks   0.675724    29         0                  0       0
# 2018-01-01       Nets   0.674937    42         1                  0       0
# 2016-01-01  Cavaliers   0.664197    51         1                  1       0
# 2018-01-01    Pistons   0.651004    41         1                  0       0
# 2018-01-01       Jazz   0.649662    50         1                  0       0
# ...

# %%
sort_by_stat_multiyr('FG3A/FG2A',2010,asc=True)
# Out:
#                TEAM_NAME  FG3A/FG2A  WINS  PLAYOFFS  FINALS_APPEARANCE  CHAMPS
# YEAR
# 2011-01-01       Hornets   0.179612    21         0                  0       0
# 2011-01-01          Jazz   0.180324    36         1                  0       0
# 2011-01-01     Grizzlies   0.185655    41         1                  0       0
# 2012-01-01     Grizzlies   0.198672    56         1                  0       0
# 2011-01-01       Bobcats   0.202681     7         0                  0       0
# 2013-01-01     Grizzlies   0.205703    50         1                  0       0
# 2011-01-01         76ers   0.211509    35         1                  0       0
# 2011-01-01       Pistons   0.212234    25         0                  0       0
# 2014-01-01  Timberwolves   0.218510    16         0                  0       0
# 2014-01-01     Grizzlies   0.225847    55         1                  0       0
# 2012-01-01         Bulls   0.232836    45         1                  0       0
# ...

# %%
sort_by_stat_multiyr('FG3_PCT',1982)
# Out:
#               TEAM_NAME  FG3_PCT  WINS  PLAYOFFS  FINALS_APPEARANCE  CHAMPS
# YEAR
# 1996-01-01      Hornets    0.428    54         1                  0       0
# 2015-01-01     Warriors    0.416    73         1                  1       0
# 2009-01-01         Suns    0.412    54         1                  0       0
# 1995-01-01      Bullets    0.407    39         0                  0       0
# 2000-01-01        Spurs    0.407    58         1                  0       0
# 1989-01-01    Cavaliers    0.407    42         1                  0       0
# 1995-01-01      Pistons    0.404    46         1                  0       0
# 2012-01-01     Warriors    0.403    47         1                  0       0
# 1995-01-01        Bulls    0.403    72         1                  1       1
# 2003-01-01        Kings    0.401    55         1                  0       0
# 2006-01-01         Suns    0.399    61         1                  0       0
# ...

# %%
year_and_playoffs=teams_master.reset_index().groupby(['YEAR','PLAYOFFS'])[['FG3_PCT','FG2_PCT','FG3A/FG2A','PTS_PER_GP','FG3A_PER_GP','FG2A_PER_GP']].mean()
year_and_playoffs
# Out:
#                       FG3_PCT   FG2_PCT  FG3A/FG2A  PTS_PER_GP  FG3A_PER_GP  \
# YEAR       PLAYOFFS
# 1983-01-01 0         0.227286  0.490028   0.025002  108.834495     2.193380
#            1         0.248688  0.502690   0.028852  110.668445     2.458079
# 1984-01-01 0         0.264429  0.489793   0.032623  107.794425     2.780488
#            1         0.277688  0.502783   0.038337  112.169970     3.293445
# 1985-01-01 0         0.272143  0.485973   0.036442  106.693380     3.071429
#            1         0.266563  0.499546   0.040467  111.762957     3.452744
# 1986-01-01 0         0.271857  0.484114   0.051486  107.339721     4.306620
#            1         0.298250  0.493424   0.058735  111.070884     4.909299
# 1987-01-01 0         0.302667  0.478000   0.058750  104.739837     4.800813
#            1         0.307706  0.494963   0.061519  109.369440     5.063845
# 1988-01-01 0         0.293111  0.476818   0.069981  104.651762     5.672087
# ...

# %%
po_yes=year_and_playoffs.reset_index().loc[year_and_playoffs.reset_index()['PLAYOFFS']==1].set_index('YEAR')
po_no=year_and_playoffs.reset_index().loc[year_and_playoffs.reset_index()['PLAYOFFS']==0].set_index('YEAR')

# %%
plt.figure(figsize=(12,9))
plt.plot(po_yes['FG3A/FG2A'],color='blue',marker='o')
plt.plot(po_no['FG3A/FG2A'],color='green',marker='o');

# %%
plt.figure(figsize=(12,9))
plt.plot(po_yes['FG3_PCT'],color='dodgerblue',marker='o')
plt.plot(po_no['FG3_PCT'],color='lime',marker='o')
plt.plot(po_yes['FG2_PCT'],color='blue',marker='o')
plt.plot(po_no['FG2_PCT'],color='green',marker='o');

# %%
plt.figure(figsize=(12,9))
plt.plot(po_yes['FG3A_PER_GP'],color='blue',marker='o')
plt.plot(po_no['FG3A_PER_GP'],color='green',marker='o');

# %%
teams_master[teams_master.index.year >1982][['TEAM_NAME','FG3_PCT','WINS','PLAYOFFS','FINALS_APPEARANCE','CHAMPS']].sort_values(by=['WINS'],ascending=False).head(30)

# %%
sort_by_stat_multiyr('FG3_PCT',1982,50)

# %%
plt.figure(figsize=(12,9))
plt.plot(sixers['PTS_PER_GP'],color='blue',label='76ers')
plt.plot(bucks['PTS_PER_GP'],color='darkgreen',label='Bucks')
plt.plot(bulls['PTS_PER_GP'],color='firebrick',label='Bulls')
plt.plot(cavaliers['PTS_PER_GP'],color='orangered',label='Cavaliers')
plt.plot(celtics['PTS_PER_GP'],color='green',label='Celtics')
plt.plot(clippers['PTS_PER_GP'],color='mistyrose',label='Clippers')
plt.plot(grizzlies['PTS_PER_GP'],color='teal',label='Grizzlies')
plt.plot(hawks['PTS_PER_GP'],color='sienna',label='Hawks')
plt.plot(heat['PTS_PER_GP'],color='black',label='Heat')
plt.plot(hornets['PTS_PER_GP'],color='aqua',label='Hornets')
plt.plot(jazz['PTS_PER_GP'],color='purple',label='Jazz')
plt.plot(kings['PTS_PER_GP'],color='blueviolet',label='Kings')
plt.plot(knicks['PTS_PER_GP'],color='darkorange',label='Knicks')
plt.plot(lakers['PTS_PER_GP'],color='yellow',label='Lakers')
plt.plot(magic['PTS_PER_GP'],color='cornflowerblue',label='Magic')
plt.plot(mavericks['PTS_PER_GP'],color='navy',label='Mavericks')
plt.plot(nets['PTS_PER_GP'],color='darkgrey',label='Nets')
plt.plot(nuggets['PTS_PER_GP'],color='gold',label='Nuggets')
plt.plot(pacers['PTS_PER_GP'],color='darkgoldenrod',label='Pacers')
plt.plot(pelicans['PTS_PER_GP'],color='seagreen',label='Pelicans')
plt.plot(pistons['PTS_PER_GP'],color='steelblue',label='Pistons')
plt.plot(raptors['PTS_PER_GP'],color='mediumvioletred',label='Raptors')
plt.plot(rockets['PTS_PER_GP'],color='red',label='Rockets')
plt.plot(spurs['PTS_PER_GP'],color='black',label='Spurs')
plt.plot(suns['PTS_PER_GP'],color='tomato',label='Suns')
plt.plot(thunder['PTS_PER_GP'],color='moccasin',label='Thunder')
plt.plot(timberwolves['PTS_PER_GP'],color='lightsteelblue',label='Timberwolves')
plt.plot(blazers['PTS_PER_GP'],color='darkred',label='Trail Blazers')
plt.plot(warriors['PTS_PER_GP'],color='khaki',label='Warriors')
plt.plot(wizards['PTS_PER_GP'],color='dodgerblue',label='Wizards')

plt.title('Points per Game Played by Team')
plt.legend();

# %%
plt.figure(figsize=(12,9))
plt.plot(sixers['FG3A/FG2A'],color='blue',label='76ers')
plt.plot(bucks['FG3A/FG2A'],color='darkgreen',label='Bucks')
plt.plot(bulls['FG3A/FG2A'],color='firebrick',label='Bulls')
plt.plot(cavaliers['FG3A/FG2A'],color='orangered',label='Cavaliers')
plt.plot(celtics['FG3A/FG2A'],color='green',label='Celtics')
plt.plot(clippers['FG3A/FG2A'],color='mistyrose',label='Clippers')
plt.plot(grizzlies['FG3A/FG2A'],color='teal',label='Grizzlies')
plt.plot(hawks['FG3A/FG2A'],color='sienna',label='Hawks')
plt.plot(heat['FG3A/FG2A'],color='black',label='Heat')
plt.plot(hornets['FG3A/FG2A'],color='aqua',label='Hornets')
plt.plot(jazz['FG3A/FG2A'],color='purple',label='Jazz')
plt.plot(kings['FG3A/FG2A'],color='blueviolet',label='Kings')
plt.plot(knicks['FG3A/FG2A'],color='darkorange',label='Knicks')
plt.plot(lakers['FG3A/FG2A'],color='yellow',label='Lakers')
plt.plot(magic['FG3A/FG2A'],color='cornflowerblue',label='Magic')
plt.plot(mavericks['FG3A/FG2A'],color='navy',label='Mavericks')
plt.plot(nets['FG3A/FG2A'],color='darkgrey',label='Nets')
plt.plot(nuggets['FG3A/FG2A'],color='gold',label='Nuggets')
plt.plot(pacers['FG3A/FG2A'],color='darkgoldenrod',label='Pacers')
plt.plot(pelicans['FG3A/FG2A'],color='seagreen',label='Pelicans')
plt.plot(pistons['FG3A/FG2A'],color='steelblue',label='Pistons')
plt.plot(raptors['FG3A/FG2A'],color='mediumvioletred',label='Raptors')
plt.plot(rockets['FG3A/FG2A'],color='red',label='Rockets')
plt.plot(spurs['FG3A/FG2A'],color='black',label='Spurs')
plt.plot(suns['FG3A/FG2A'],color='tomato',label='Suns')
plt.plot(thunder['FG3A/FG2A'],color='moccasin',label='Thunder')
plt.plot(timberwolves['FG3A/FG2A'],color='lightsteelblue',label='Timberwolves')
plt.plot(blazers['FG3A/FG2A'],color='darkred',label='Trail Blazers')
plt.plot(warriors['FG3A/FG2A'],color='khaki',label='Warriors')
plt.plot(wizards['FG3A/FG2A'],color='dodgerblue',label='Wizards')

plt.title('3 Pt FG Attempts per 2 Pt FG Attempts by Team')
plt.legend();

# %%
players.head()
# Out:
#                           name                                    positions  \
# year
# 1990-01-01      Alaa Abdelnaby  [<Position.POWER_FORWARD: 'POWER FORWARD'>]
# 1990-01-01  Mahmoud Abdul-Rauf      [<Position.POINT_GUARD: 'POINT GUARD'>]
# 1990-01-01          Mark Acres                [<Position.CENTER: 'CENTER'>]
# 1990-01-01       Michael Adams      [<Position.POINT_GUARD: 'POINT GUARD'>]
# 1990-01-01        Mark Aguirre  [<Position.SMALL_FORWARD: 'SMALL FORWARD'>]
#
#             age                         team  games_played  games_started  \
# year
# 1990-01-01   22  Team.PORTLAND_TRAIL_BLAZERS            43              0
# 1990-01-01   21          Team.DENVER_NUGGETS            67             19
# 1990-01-01   28           Team.ORLANDO_MAGIC            68              0
# 1990-01-01   28          Team.DENVER_NUGGETS            66             66
# 1990-01-01   31         Team.DETROIT_PISTONS            78             13
#
# ...

# %%
players.loc[(players['3PA/GP']>=3) & (players['games_played'] >= 20)][['name','season','3fg_pct','attempted_three_point_field_goals','Salary','salary_normalized_%']].sort_values(by=['3fg_pct'],ascending=False).head(30)
# Out:
#                   name  season   3fg_pct  attempted_three_point_field_goals  \
# 2118        Tim Legler    1995  0.522449                                245
# 6978      Jason Kapono    2006  0.514286                                210
# 12220   Doug McDermott    2017  0.493671                                 79
# 10721      Kyle Korver    2014  0.492205                                449
# 11669      Kyle Korver    2016  0.485000                                200
# 8437       Mike Miller    2009  0.479532                                171
# 6068       Joe Johnson    2004  0.478378                                370
# 4116       Brent Barry    2000  0.475983                                229
# 3320        Dell Curry    1998  0.475862                                145
# 1991      Hubert Davis    1995  0.475655                                267
# 12652       Joe Harris    2018  0.474093                                386
# ...

# %%
players[['name','season','3fg_pct','3PA/GP','Salary','salary_normalized_%']].sort_values(by=['salary_normalized_%'],ascending=False).head(30)
# Out:
#                    name  season   3fg_pct    3PA/GP       Salary  \
# 2545     Michael Jordan    1996  0.373737  3.621951  $30,140,000
# 2996     Michael Jordan    1997  0.238095  1.536585  $33,140,000
# 2024      Patrick Ewing    1995  0.142857  0.368421  $18,724,000
# 2920      Patrick Ewing    1997  0.000000  0.076923  $20,500,000
# 391          Larry Bird    1991  0.406250  2.844444   $7,070,000
# 2492       Horace Grant    1996  0.166667  0.089552  $14,857,000
# 3352      Patrick Ewing    1998  0.000000  0.052632  $18,500,000
# 5102      Kevin Garnett    2002  0.281690  0.865854  $25,200,000
# 5531      Kevin Garnett    2003  0.255814  0.524390  $28,000,000
# 5247   Shaquille O'Neal    2002       NaN  0.000000  $23,571,429
# 10043       Kobe Bryant    2013  0.187500  2.666667  $30,453,000
# 6144   Shaquille O'Neal    2004       NaN  0.000000  $27,696,430
# 4682      Kevin Garnett    2001  0.318966  1.432099  $22,400,000
# ...

# %%
players.loc[players['season'] == 2018][['name','season','3fg_pct','3PA/GP','Salary','salary_normalized_%']].sort_values(by=['salary_normalized_%'],ascending=False).head(30)
# Out:
#                         name  season   3fg_pct     3PA/GP       Salary  \
# 12561          Stephen Curry    2018  0.437037  11.739130  $37,457,154
# 12953      Russell Westbrook    2018  0.289538   5.630137  $35,665,000
# 12701           LeBron James    2018  0.339450   5.945455  $35,654,150
# 12849             Chris Paul    2018  0.357746   6.120690  $35,654,150
# 12761             Kyle Lowry    2018  0.346578   6.969231  $32,700,000
# 12645          Blake Griffin    2018  0.362069   6.960000  $31,873,932
# 12662         Gordon Hayward    2018  0.333333   3.208333  $31,214,295
# 12648           James Harden    2018  0.367704  13.179487  $30,570,000
# 12626            Paul George    2018  0.385733   9.831169  $30,560,700
# 12547            Mike Conley    2018  0.363850   6.085714  $30,521,115
# 12587           Kevin Durant    2018  0.353093   4.974359  $30,000,000
# 12798           Paul Millsap    2018  0.364780   2.271429  $29,230,769
# ...

# %%
players[['name','season','3fg_pct','3PA/GP','Salary','salary_normalized_%']].sort_values(by=['3PA/GP'],ascending=False).head(30)
# Out:
#                           name  season   3fg_pct     3PA/GP       Salary  \
# year
# 2018-01-01        James Harden    2018  0.367704  13.179487  $30,570,000
# 2018-01-01       Stephen Curry    2018  0.437037  11.739130  $37,457,154
# 2015-01-01       Stephen Curry    2015  0.453725  11.215190  $11,370,786
# 2017-01-01        James Harden    2017  0.367036  10.027778  $28,299,399
# 2016-01-01       Stephen Curry    2016  0.410646   9.987342  $12,112,359
# 2018-01-01         Paul George    2018  0.385733   9.831169  $30,560,700
# 2017-01-01       Stephen Curry    2017  0.423154   9.823529  $34,682,550
# 2016-01-01        James Harden    2016  0.346561   9.333333  $26,540,100
# 2018-01-01        Kemba Walker    2018  0.355677   8.914634  $12,000,000
# 2018-01-01         Eric Gordon    2018  0.360000   8.823529  $13,500,375
# 2016-01-01         Eric Gordon    2016  0.372163   8.813333  $12,385,665
# 2017-01-01         Eric Gordon    2017  0.358553   8.811594  $12,943,020
# ...

# %%
players['year']=pd.to_datetime(players.season.astype(str))

# %%
players.set_index('year', inplace=True)

# %%
players.head()

# %%
players.loc[(players['3fg_pct']>=.35) & (players['3PA/GP']>=3)].groupby(['season'])[['salary_normalized_%']]

# %%
countofshooters=players.loc[(players['3fg_pct']>=.35) & (players['FG3A_rank'] <=100)].groupby(['season'])[['salary_normalized_%']].count()

# %%
avg_sal_3pt_shooters=players.loc[(players['3fg_pct']>=.35) & (players['FG3A_rank'] <=100)].groupby(['season'])[['salary_normalized_%']].mean()

# %%
count_3pt_shooters=players.loc[(players['3fg_pct']>=.35) & (players['3PA/GP']>=3)].groupby(['season'])[['salary_normalized_%']].count()

# %%
avgsal3ptmakes=players.loc[players['FG3M_rank'] <=20].groupby(['season'])[['salary_normalized_%']].mean()

# %%
# avg_sal_3pt_shooters=players.loc[(players['3fg_pct']>=.35) & (players['3PA/GP']>=3)].groupby(['season'])[['salary_normalized_%']].mean()

# %%
plt.figure(figsize=(12,9))
plt.plot(countofshooters,color='blue',marker='o');

# %%
plt.figure(figsize=(12,9))
plt.plot(count_3pt_shooters,color='blue',marker='o');

# %%
countofshooters.plot.bar()
plt.title('Count of over 35% and top 100 attempts 3 point shooters');

# %%
count_3pt_shooters.plot.bar()
plt.title('Count of over 35% and over 3 attempts per game 3 point shooters');

# %%
avg_sal_3pt_shooters.plot.bar()
plt.title('Avg Salary of Over 35% 3 Point Shooters');

# %%
avgsal3ptmakes.plot.bar()
plt.title('Avg Salary of Top 20 3pt Makes');

# %%
y=players.loc[(players['3PA/GP']>=3)]['salary_normalized_%']
x=players.loc[(players['3PA/GP']>=3)]['3fg_pct']

plt.figure(figsize=(12,9))
plt.scatter(x, y, color='blue')
plt.xlabel('3 Pt FG %')
plt.ylabel('Salary (Normalized)')
plt.show()

# %%
teams_master.head()
# Out:
#             Unnamed: 0     TEAM_ID     TEAM_CITY TEAM_NAME  GP  WINS  LOSSES  \
# YEAR
# 1983-01-01          34  1610612755  Philadelphia     76ers  82    52      30
# 1984-01-01          35  1610612755  Philadelphia     76ers  82    58      24
# 1985-01-01          36  1610612755  Philadelphia     76ers  82    54      28
# 1986-01-01          37  1610612755  Philadelphia     76ers  82    45      37
# 1987-01-01          38  1610612755  Philadelphia     76ers  82    36      46
#
#             WIN_PCT  CONF_RANK  DIV_RANK  PO_WINS  PO_LOSSES  CONF_COUNT  \
# YEAR
# 1983-01-01    0.634          3         2        2          3        11.0
# 1984-01-01    0.707          3         2        8          5        11.0
# 1985-01-01    0.659          3         2        6          6        11.0
# 1986-01-01    0.549          5         2        2          3        11.0
# 1987-01-01    0.439         10         4        0          0        11.0
#
# ...

# %%
y=teams_master['FG3A_PER_GP']
x=teams_master['FG2A_PER_GP']

plt.figure(figsize=(12,9))
plt.scatter(x, y, c=teams_master['PLAYOFFS'])
plt.xlabel('2 Pt Attempted Per Game')
plt.ylabel('3 Pt Attempted Per Game')
plt.show()

# %%
y=teams_master['FG3_PCT']
x=teams_master['FG2_PCT']

plt.figure(figsize=(12,9))
plt.scatter(x, y, c=teams_master['PLAYOFFS'])
plt.xlabel('2 Pt Percentage')
plt.ylabel('3 Pt Percentage')
plt.show()

# %%
y=teams_master[teams_master.index.year > 2010]['FG3_PCT']
x=teams_master[teams_master.index.year > 2010]['FG2_PCT']

plt.figure(figsize=(12,9))
plt.scatter(x, y, c=teams_master[teams_master.index.year > 2010]['PLAYOFFS'])
plt.xlabel('2 Pt Percentage')
plt.ylabel('3 Pt Percentage')
plt.show()

# %%
y=teams_master[teams_master.index.year > 2010]['FG3A_PER_GP']
x=teams_master[teams_master.index.year > 2010]['FG2A_PER_GP']

plt.figure(figsize=(12,9))
plt.scatter(x, y, c=teams_master[teams_master.index.year > 2010]['PLAYOFFS'])
plt.xlabel('2 Pt Attempted Per Game')
plt.ylabel('3 Pt Attempted Per Game')
plt.show()
